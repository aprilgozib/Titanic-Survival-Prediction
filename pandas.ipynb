# %% [markdown]
# # Pandas.DataFrame class structure
# class pandas.DataFrame(data=None, index=None, columns=None, copy=None)
# Series -> 1 dimension, DataFrame -> 2 dimension array

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(0)
arr = np.random.randint(10, size = (2, 2)) # 2*2 random array
print(arr)
# Out:
# [[5 0]
#  [3 3]]

# %%
df1 = pd.DataFrame(arr, copy = False)
df2 = pd.DataFrame(arr, copy = True)

# %%
arr[0,0] = 99
print(df1)
# Out:
#     0  1
# 0  99  0
# 1   3  3

# %%
print(df2)
# Out:
#    0  1
# 0  5  0
# 1  3  3

# %%
data = {'A' : [1,2], 'B' : [3,4]}
df = pd.DataFrame(data = data)
print(df)
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
data = np.array([1,2,],[3,4])
df = pd.DataFrame(data = data, index = ['row1', 'row2'], columns = ['col1', 'col2'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data = np.array([1,2,],[3,4])
#       2 df = pd.DataFrame(data = data, index = ['row1', 'row2'], columns = ['col1', 'col2'])
#       3 print(df)
#
# TypeError: Field elements must be 2- or 3-tuples, got '3'
